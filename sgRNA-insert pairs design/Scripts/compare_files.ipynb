# %%
import pandas as pd

# Load both CSV files
df1 = pd.read_csv('../Example_Data/sgRNA_insert_list.csv')
df2 = pd.read_csv('../Example_Data/example_sgRNA_insert.csv')


# Define the columns you want to compare
columns_to_compare = [
    "gene", "parent aa", "parent codon", "aa position",
    "child codon", "nt position", "dist mut pam", "pam"
]

# Subset the dataframes to only the relevant columns
df1_subset = df1[columns_to_compare].copy()
df2_subset = df2[columns_to_compare].copy()

# Remove duplicate rows if needed (optional)
df1_unique = df1_subset.drop_duplicates()
df2_unique = df2_subset.drop_duplicates()

# Find rows unique to df1
unique_to_df1 = pd.merge(df1_unique, df2_unique, how='outer', indicator=True)\
                  .query('_merge == "left_only"')\
                  .drop(columns=['_merge'])

# Find rows unique to df2
unique_to_df2 = pd.merge(df2_unique, df1_unique, how='outer', indicator=True)\
                  .query('_merge == "left_only"')\
                  .drop(columns=['_merge'])

# Print results
print("\nRows unique to File 1:")
print(unique_to_df1.to_string(index=False))

print("\nRows unique to File 2:")
print(unique_to_df2.to_string(index=False))
# Out:
# Rows unique to File 1:
# gene parent aa parent codon  aa position child codon  nt position  dist mut pam pam
# alaA       LEU          CTT        107.0         TTC          319           -18 CGG
# alaA       LEU          CTT        107.0         TTC          319           -12 TGG
# alaA       LEU          CTT        107.0         TTC          319            -4 CGG
# alaA       ALA          GCA        126.0         GTA          376           -21 CGG
# alaA       ALA          GCA        126.0         GTA          376            -7 TGG
# alaA       ALA          GCA        126.0         GTA          376            -2 CCT
# alaA       ALA          GCA        126.0         GTA          376            12 CCC
# alaA       VAL          GTC         13.0         ATA           37           -29 CCC
# alaA       VAL          GTC         13.0         ATA           37           -16 CCA
# alaA       VAL          GTC         13.0         ATA           37            15 CCG
# alaA       PRO          CCT        167.0         TCG          499           -27 CCT
# alaA       PRO          CCT        167.0         TCG          499            30 CCC
# alaA       MET          ATG        191.0         ATA          571           -27 CGG
# alaA       MET          ATG        191.0         ATA          571           -22 CGG
# alaA       MET          ATG        191.0         ATA          571           -28 CCG
# alaA       MET          ATG        191.0         ATA          571           -13 CCA
# alaA       ALA          GCA        197.0         GTA          589           -16 TGG
# alaA       ALA          GCA        197.0         GTA          589            -7 TGG
# alaA       PRO          CCG        225.0         GCA          673            15 CCT
# alaA       LEU          CTG        226.0         ATG          676            12 CCT
# alaA       VAL          GTT        244.0         ATA          730           -21 CGG
# alaA       VAL          GTT        244.0         ATA          730           -28 CCT
# alaA       VAL          GTT        244.0         ATA          730            -3 CCG
# alaA       VAL          GTT        244.0         ATA          730            12 CCG
# alaA       THR          ACC        288.0         GCA          862            -7 CCA
# alaA       THR          ACC        301.0         ATG          901           -27 TGG
# alaA       GLY          GGC        303.0         TCG          907            -4 CCC
# alaA       GLY          GGC        303.0         TCG          907            27 CCG
# alaA       ASN          AAC        311.0         AAG          931           -24 TGG
# alaA       ASN          AAC        311.0         AAG          931           -21 CGG
# alaA       ASN          AAC        311.0         AAG          931           -28 CCC
# alaA       ASP          GAT        319.0         AAT          955           -14 TGG
# alaA       ASP          GAT        319.0         AAT          955           -21 CCG
# alaA       ALA          GCC        340.0         GTA         1018           -12 CCC
# alaA       LYS          AAA        341.0         AGG         1021           -15 CCC
# alaA       LYS          AAA        341.0         AGG         1021            -1 CCA
# alaA       VAL          GTC        385.0         ATA         1153           -21 CCG
# alaA       VAL          GTC        385.0         ATA         1153            -5 CCG
# alaA       ALA          GCG        396.0         ACT         1186             9 CCT
# alaA       GLY          GGT        401.0         TCG         1201            -6 CCT
# alaA       PRO          CCG         45.0         TCG          133           -12 CGG
# alaA       PRO          CCG         45.0         TCG          133            -6 CCC
# alaA       PRO          CCG         45.0         TCG          133            -1 CCC
# alaA       PRO          CCG         45.0         TCG          133            30 CCT
# alaA       GLU          GAA         53.0         GAC          157           -18 CGG
# alaA       GLU          GAA         53.0         GAC          157           -29 CCA
# alaA       GLU          GAA         53.0         GAC          157           -25 CCC
# alaA       GLU          GAA         53.0         GAC          157            -5 CCA
# alaA       GLU          GAA         53.0         GAC          157             6 CCT
# alaA       GLU          GAA         53.0         GAC          157            27 CCT
# alaA       ILE          ATC         54.0         GTA          160           -21 CGG
# alaA       ILE          ATC         54.0         GTA          160           -28 CCC
# alaA       ILE          ATC         54.0         GTA          160            -8 CCA
# alaA       ILE          ATC         54.0         GTA          160            24 CCT
# alaA       VAL          GTT         56.0         ATA          166           -27 CGG
# alaA       VAL          GTT         56.0         ATA          166           -14 CCA
# alaA       VAL          GTT         56.0         ATA          166            -3 CCT
# alaA       VAL          GTT         56.0         ATA          166            18 CCT
# alaA       ALA          GCT         65.0         TCG          193            -9 CCT
# alaA       ALA          GCT         65.0         TCG          193            -5 CCT
# alaA       ALA          GCT         65.0         TCG          193            -1 CCG
# alaA       ARG          CGT         91.0         TCG          271           -13 AGG
#
# Rows unique to File 2:
# gene parent aa parent codon  aa position child codon  nt position  dist mut pam pam
# alaA       LEU          CTT        107.0         TTT          319           -18 CGG
# alaA       LEU          CTT        107.0         TTT          319           -12 TGG
# alaA       LEU          CTT        107.0         TTT          319            -4 CGG
# alaA       ALA          GCA        126.0         GTC          376            -7 TGG
# alaA       ALA          GCA        126.0         GTC          376            12 CCC
# alaA       SER          TCG        137.0         GCT          409           -14 TGG
# alaA       SER          TCG        137.0         GCT          409            -7 CGG
# alaA       SER          TCG        137.0         GCT          409            -4 CGG
# alaA       SER          TCG        137.0         GCT          409           -29 CCA
# alaA       SER          TCG        137.0         GCT          409           -21 CCC
# alaA       SER          TCG        137.0         GCT          409           -10 CCG
# alaA       ASP          GAC        157.0         AAC          469           -16 CCT
# alaA       PRO          CCT        167.0         TCT          499           -27 CCT
# alaA       PRO          CCT        167.0         TCT          499            30 CCC
# alaA       MET          ATG        191.0         ATC          571           -27 CGG
# alaA       MET          ATG        191.0         ATC          571           -22 CGG
# alaA       MET          ATG        191.0         ATC          571           -28 CCG
# alaA       MET          ATG        191.0         ATC          571           -13 CCA
# alaA       ALA          GCA        197.0         GTC          589            -7 TGG
# alaA       PRO          CCG        225.0         GCT          673            15 CCT
# alaA       SER          TCG        239.0         CCT          715            -6 CGG
# alaA       SER          TCG        239.0         CCT          715           -27 CCT
# alaA       SER          TCG        239.0         CCT          715           -19 CCA
# alaA       SER          TCG        239.0         CCT          715           -13 CCT
# alaA       SER          TCG        239.0         CCT          715            12 CCG
# alaA       SER          TCG        239.0         CCT          715            27 CCG
# alaA       VAL          GTT        244.0         ATC          730           -21 CGG
# alaA       VAL          GTT        244.0         ATC          730           -28 CCT
# alaA       VAL          GTT        244.0         ATC          730            -3 CCG
# alaA       VAL          GTT        244.0         ATC          730            12 CCG
# alaA       THR          ACC        288.0         GCT          862            -7 CCA
# alaA       GLY          GGC        303.0         TCT          907            -4 CCC
# alaA       GLY          GGC        303.0         TCT          907            27 CCG
# alaA       ASN          AAC        318.0         TCT          952           -11 TGG
# alaA       ASN          AAC        318.0         TCT          952           -18 CCG
# alaA       ASP          GAT        319.0         AAC          955           -14 TGG
# alaA       ASP          GAT        319.0         AAC          955           -21 CCG
# alaA       ALA          GCC        340.0         GTC         1018           -12 CCC
# alaA       LYS          AAA        341.0         AGA         1021           -15 CCC
# alaA       LYS          AAA        341.0         AGA         1021            -1 CCA
# alaA       LEU          CTG        390.0         CAA         1168           -20 CCG
# alaA       LEU          CTG        390.0         CAA         1168            27 CCT
# alaA       ALA          GCG        396.0         ACC         1186             9 CCT
# alaA       GLY          GGT        401.0         TCT         1201            -6 CCT
# alaA       PRO          CCG         45.0         TCT          133           -12 CGG
# alaA       PRO          CCG         45.0         TCT          133            -6 CCC
# alaA       PRO          CCG         45.0         TCT          133            -1 CCC
# alaA       PRO          CCG         45.0         TCT          133            30 CCT
# alaA       ASP          GAC         49.0         GAA          145           -24 CGG
# alaA       ASP          GAC         49.0         GAA          145            -6 CGG
# alaA       ASP          GAC         49.0         GAA          145           -18 CCC
# alaA       ASP          GAC         49.0         GAA          145           -13 CCC
# alaA       ASP          GAC         49.0         GAA          145            18 CCT
# alaA       ILE          ATC         54.0         GTC          160           -28 CCC
# alaA       ILE          ATC         54.0         GTC          160            24 CCT
# alaA       VAL          GTT         56.0         ATC          166           -27 CGG
# alaA       VAL          GTT         56.0         ATC          166           -14 CCA
# alaA       VAL          GTT         56.0         ATC          166            -3 CCT
# alaA       VAL          GTT         56.0         ATC          166            18 CCT
# alaA       ALA          GCT         65.0         TCT          193            -9 CCT
# alaA       ALA          GCT         65.0         TCT          193            -5 CCT
# alaA       ALA          GCT         65.0         TCT          193            -1 CCG
# alaA       ARG          CGT         91.0         TCT          271           -13 AGG
# alaA       ARG          CGT         91.0         TCT          271            -6 TGG
# alaA       ARG          CGT         91.0         TCT          271           -15 CCA
